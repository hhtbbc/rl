# %% [markdown]
# # 第 25 节: 最终评估
#
# ## 评估结构
#
# - Part A: 理论题 (40%), 30 分钟
# - Part B: 编程题 (40%), 60 分钟
# - Part C: 开放题 (20%), 30 分钟

# %% [markdown]
# ## Part A: 理论题
#
# ### A1. Bellman 方程
# 写出有限 MDP 的 Bellman 最优方程 (矩阵形式和逐状态形式), 并解释 contraction 的含义.
#
# ### A2. Policy Gradient
# 完整推导策略梯度定理: 从 J(theta) = E[R(tau)] 到 grad J = E[grad log pi * G].
#
# ### A3. GAE
# 写出 GAE 的递推公式并解释 lambda 从 0 到 1 时 advantage 估计的变化.
#
# ### A4. TRPO vs PPO
# 对比 TRPO 和 PPO 的约束方式, 解释为什么 PPO 在实践中更受欢迎.
#
# ### A5. 识别错误
# 下面的 Actor-Critic 代码有什么问题?
# ```python
# actor_loss = -(log_prob * (reward + gamma * critic(next_state) - critic(state))).mean()
# actor_loss.backward()  # 同时更新 actor 和 critic
# ```

# %% [markdown]
# ## Part B: 编程题
#
# ### B1. 实现 n-step TD Prediction
# 从头实现 n-step TD 价值预测, 在 RandomWalk 上验证.
#
# ### B2. 修复有 bug 的 PPO
# 给出的 PPO 代码有至少 3 个 bug, 找出并修复.
#
# ### B3. 添加 Entropy Bonus
# 给一个没有 entropy bonus 的 A2C 实现添加 entropy bonus, 观察训练效果变化.
#
# ### B4. 从零实现 Q-Learning
# 在 CliffWalking 上从零实现 Q-Learning (不调用 rl_course.agents).

# %% [markdown]
# ## Part C: 开放题
#
# ### C1. 设计奖励函数
# 为训练四足机器人行走设计奖励函数. 讨论: 稀疏 vs 稠密奖励的权衡, 如何避免 reward hacking.
#
# ### C2. 算法选择
# 以下场景应选择什么算法? 为什么?
# - (a) 下围棋
# - (b) 机器人抓取 (连续动作, 稀疏奖励)
# - (c) 推荐系统 (大量用户数据, 离线学习)
# - (d) 自动驾驶 (安全关键)

# %% [markdown]
# ## 评分标准
#
# | 题目 | 满分 | 及格线 |
# |------|------|--------|
# | A1-A5 理论 | 40 | 24 |
# | B1-B4 编程 | 40 | 24 |
# | C1-C2 开放 | 20 | 12 |
# | 总计 | 100 | 60 |

# %% [markdown]
# ## 恭喜完成课程!
#
# 你现在具备了:
# - RL 核心理论的深入理解
# - 从零实现主要算法的能力
# - 调试和分析 RL 实验的能力
# - 阅读 RL 论文的基础
# - 面试所需的理论与实践基础
#
# ### 下一步
# - 阅读 Sutton & Barto 完整版
# - 在更难的环境中实践 (Atari, MuJoCo)
# - 关注最新 RL 研究 (RLHF, Decision Transformer 等)
# - 参与开源项目 (CleanRL, Stable-Baselines3)
